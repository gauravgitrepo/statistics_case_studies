# %% [markdown]
# ### Credit Card Case Study

# %% [markdown]
# #### Importing Libraries

# %%
### Installing Pandas Profiling
###pip install pandas_profiling

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas_profiling

# %% [markdown]
# #### Importing Input Files

# %%
Inp1=pd.read_csv(r'C:\Users\goura\Downloads\Compressed\Gaurav_data_science\Basic Python Stats Modelling\Assignments\Case Studies\Credit card case study\4. Pandas Case Study 2 - Credit Card Case Study\Customer Acqusition.csv')

# %%
Inp2=pd.read_csv(r'C:\Users\goura\Downloads\Compressed\Gaurav_data_science\Basic Python Stats Modelling\Assignments\Case Studies\Credit card case study\4. Pandas Case Study 2 - Credit Card Case Study\Repayment.csv')

# %%
Inp3=pd.read_csv(r'C:\Users\goura\Downloads\Compressed\Gaurav_data_science\Basic Python Stats Modelling\Assignments\Case Studies\Credit card case study\4. Pandas Case Study 2 - Credit Card Case Study\Spend.csv')

# %%
Inp1
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 0     1       A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...  ...         ...       ...       ...     ...            ...
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
Inp2
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# 3        4.0       A1  25-Jan-04  437555.12         NaN
# 4        5.0       A1  17-Jan-05  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1518     NaN      NaN        NaN        NaN         NaN
# 1519     NaN      NaN        NaN        NaN         NaN
# 1520     NaN      NaN        NaN        NaN         NaN
# 1521     NaN      NaN        NaN        NaN         NaN
# 1522     NaN      NaN        NaN        NaN         NaN
#
# [1523 rows x 5 columns]

# %%
Inp3
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %% [markdown]
# #### Inspecting Input Files
#
# ###### Check for dtypes of variables,missings,no.of rows and columns

# %%
Inp1.info()

## Inp1 has no missings,dtypes of variables are also valid
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
# No          100 non-null int64
# Customer    100 non-null object
# Age         100 non-null int64
# City        100 non-null object
# Product     100 non-null object
# Limit       100 non-null float64
# Company     100 non-null object
# Segment     100 non-null object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
Inp2.info()

##All variables have valid dtypes except month,vars have missing values,one blank column(Can we drop this column at this stage?)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1523 entries, 0 to 1522
# Data columns (total 5 columns):
# SL No:        1499 non-null float64
# Customer      1500 non-null object
# Month         1500 non-null object
# Amount        1500 non-null float64
# Unnamed: 4    0 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 59.6+ KB

# %%
Inp2.drop(columns='Unnamed: 4',inplace=True)

# %%
Inp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1523 entries, 0 to 1522
# Data columns (total 4 columns):
# SL No:      1499 non-null float64
# Customer    1500 non-null object
# Month       1500 non-null object
# Amount      1500 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 47.7+ KB

# %%
Inp3.info()

##All vars have valid dtype,no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
# Sl No:      1500 non-null int64
# Customer    1500 non-null object
# Month       1500 non-null object
# Type        1500 non-null object
# Amount      1500 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 58.7+ KB

# %% [markdown]
# ### Creating Summaries/(Pandas Profiling or UDF's)

# %%
### Using PANDAS PROFILING

# %%
report1=pandas_profiling.ProfileReport(Inp1)

# %%
report1.to_file(output_file='Inp1.html')

# %%
report2=pandas_profiling.ProfileReport(Inp2)

# %%
report2.to_file(output_file='Inp2.html')

# %%
report3=pandas_profiling.ProfileReport(Inp3)

# %%
report3.to_file(output_file='Inp3.html')

# %%
#### Creating UDF's

#### Differentiating Categorical and Continous Variable

# %%
Conti_Vars1=Inp1.loc[:,(Inp1.dtypes == 'int64')|(Inp1.dtypes == 'float64')]
Catog_Vars1=Inp1.loc[:,(Inp1.dtypes == 'object')]

Conti_Vars2=Inp2.loc[:,(Inp2.dtypes == 'int64')|(Inp2.dtypes == 'float64')]
Catog_Vars2=Inp2.loc[:,(Inp2.dtypes == 'object')]

Conti_Vars3=Inp3.loc[:,(Inp3.dtypes == 'int64')|(Inp3.dtypes == 'float64')]
Catog_Vars3=Inp3.loc[:,(Inp3.dtypes == 'object')]


###Conti_Vars2=Inp2.select_dtypes(['int64','float64'])
###Catog_Vars2=Inp2.select_dtypes('object')


#### we can even create a UDFs for differtiating the variables(But it will be a 2D array)
###def Vars_Seperator(x):
    ###return ([x.loc[:,(x.dtypes == 'int64')|(x.dtypes == 'float64')], x.loc[:,(x.dtypes == 'object')]])

# %%
##Conti_Vars1
##Conti_Vars2
##Conti_Vars3
##Catog_Vars1
##Catog_Vars2
##Catog_Vars3

# %%
### UDF For Continous Variable Summary

def Conti_Vars_Summary(x):
    return pd.Series([x.count(),x.isnull().sum(),x.sum(),x.mean(),x.median(),x.var(),x.std(),x.min(),x.quantile(0.01),
                     x.quantile(0.05),x.quantile(0.10),x.quantile(0.25),x.quantile(0.50),x.quantile(0.75),
                     x.quantile(0.90),x.quantile(0.95),x.quantile(0.99),x.max()],index=['N','NMISS','SUM','MEAN','MEDIAN','VAR',
                                                                                       'STD','MIN','P1','P5','P10','P25','P50','P75','P90',
                                                                                       'P95','P99','MAX'])

# %%
### UDF For Categorical Variable Summary

def Catog_Vars_Summary(x):
    Mode= x.value_counts().sort_values(ascending=False)[0:1].reset_index()
    return pd.Series([x.count(),x.isnull().sum(),Mode.iloc[0,0],Mode.iloc[0,1],
                     round(Mode.iloc[0,1]*100/x.count(),2)],index=['N','NMISS','MODE','FREQ','PERCENT'])

# %%
Catog_Vars1.Company.unique()
# Out:
# array(['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11',
#        'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21', 'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29',
#        'C30', 'C31', 'C32', 'C33', 'C34', 'C35', 'C36', 'C37', 'C38',
#        'C39', 'C40', 'C41'], dtype=object)

# %%
Catog_Vars3.Type.unique()
# Out:
# array(['JEWELLERY', 'PETRO', 'CLOTHES', 'FOOD', 'CAMERA', 'SANDALS',
#        'CAR', 'BIKE', 'AUTO', 'SHOPPING', 'AIR TICKET', 'BUS TICKET',
#        'TRAIN TICKET', 'RENTAL', 'MOVIE TICKET'], dtype=object)

# %%
### UDF For Missing Value Imputation

def missing_value_imputation(x,stats='mean'):
    if (x.dtypes == 'int64') | (x.dtypes == 'float64'):
        x = x.fillna(x.mean() if stats == 'mean' else x.fillna(x.median())) 
    else:
        x = x.fillna(x.mode())
    return x

# %% [markdown]
# ### Outlier Treatments

# %%
## we can use 2 methods to check skewness
   ##a.) Boxplots b.) skew method
    
## creating UDFs
def skew_measure(x):
    return x.skew()

# %%
##skew_measure(Conti_Vars1)
##skew_measure(Conti_Vars2)
skew_measure(Conti_Vars3)

##Conti_Vars1.boxplot()
# Out:
# Sl No:    0.0000
# Amount    0.0868
# dtype: float64

# %%
Conti_Vars_Summary1=Conti_Vars1.apply(Conti_Vars_Summary)
Conti_Vars_Summary2=Conti_Vars2.apply(Conti_Vars_Summary)
Conti_Vars_Summary3=Conti_Vars3.apply(Conti_Vars_Summary)

# %%
Conti_Vars_Summary3.round(1)
# Out:
#            Sl No:        Amount
# N          1500.0  1.500000e+03
# NMISS         0.0  0.000000e+00
# SUM     1125750.0  3.646441e+08
# MEAN        750.5  2.430960e+05
# MEDIAN      750.5  2.392104e+05
# VAR      187625.0  1.997969e+10
# STD         433.2  1.413495e+05
# MIN           1.0  7.203000e+02
# P1           16.0  8.166200e+03
# P5           76.0  2.661850e+04
# P10         150.9  5.053740e+04
# P25         375.8  1.226065e+05
# P50         750.5  2.392104e+05
# P75        1125.2  3.616176e+05
# P90        1350.1  4.455653e+05
# P95        1425.0  4.709770e+05
# P99        1485.0  4.960739e+05
# MAX        1500.0  4.997935e+05

# %%
Catog_Vars_Summary1=Catog_Vars1.apply(Catog_Vars_Summary)
Catog_Vars_Summary2=Catog_Vars2.apply(Catog_Vars_Summary)
Catog_Vars_Summary3=Catog_Vars3.apply(Catog_Vars_Summary)

# %%
Catog_Vars_Summary1
# Out:
#         Customer    City Product Company Segment
# N            100     100     100     100     100
# NMISS          0       0       0       0       0
# MODE         A21  COCHIN    Gold      C6    Govt
# FREQ           1      20      38       4      29
# PERCENT        1      20      38       4      29

# %% [markdown]
# ### Missing Value Imputation

# %%
## Dropping the rows from the data as values for those rows is null for all variables
## we have not use UDF as value for all variables is null.

##Inp2.info()

Inp2.dropna(how='all',axis=0,inplace=True)

# %%
Inp2.tail()
# Out:
#       SL No: Customer      Month     Amount
# 1495  1496.0      A67   9-May-05   55638.77
# 1496  1497.0      A68  10-May-06  319836.49
# 1497  1498.0      A69  11-Jul-06  247628.45
# 1498  1499.0      A70  12-Aug-05  454016.51
# 1499  1500.0      A71  13-Sep-04   56286.33

# %% [markdown]
# ## Working On Actual Dataset

# %%
##Following are some of Mr. Watson’s questions to a Consultant (like you) to understand the
##customers spend & repayment behavior.
##1. In the above dataset,
##a. In case age is less than 18, replace it with mean of age values.
##b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
##(customer’s limit provided in acquisition table is the per transaction limit on his card)
##c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
###a. In case age is less than 18, replace it with mean of age values.

# %%
Inp1.Age.mean()
# Out:
# 46.49

# %%
Inp1.Age=np.where(Inp1.Age<18,Inp1.Age.mean(),Inp1.Age)

# %%
Inp1.sort_values('Age')
# Out:
#     No Customer   Age        City   Product     Limit Company        Segment
# 32  33      A33  19.0      BOMBAY  Platimum   10002.0     C15   Salaried_MNC
# 52  53      A53  21.0       DELHI  Platimum  100003.0     C15  Normal Salary
# 42  43      A43  21.0   BANGALORE      Gold  500000.0     C25  Self Employed
# 26  27      A27  24.0     CHENNAI      Gold  500000.0      C9  Self Employed
# 85  86      A86  25.0  TRIVANDRUM    Silver  100002.0      C9           Govt
# ..  ..      ...   ...         ...       ...       ...     ...            ...
# 63  64      A64  77.0       DELHI      Gold  500000.0     C26   Salaried_MNC
# 91  92      A92  78.0   BANGALORE      Gold  500000.0     C15           Govt
# 38  39      A39  78.0  TRIVANDRUM  Platimum  500000.0     C21   Salaried_MNC
# 16  17      A17  78.0      BOMBAY      Gold  500000.0     C17  Self Employed
# 8    9       A9  79.0     CHENNAI    Silver  100003.0      C9           Govt
#
# [100 rows x 8 columns]

# %%
###b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
###(customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
Inp3
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %%
Inp1
# Out:
#      No Customer   Age        City   Product     Limit Company        Segment
# 0     1       A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3  34.0      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4  47.0      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5  56.0   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...   ...         ...       ...       ...     ...            ...
# 95   96      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
Inp4=Inp1.drop(columns=['No','Age','City','Product','Company','Segment'])

# %%
Inp4
# Out:
#    Customer     Limit
# 0        A1  500000.0
# 1        A2  100000.0
# 2        A3   10000.0
# 3        A4   10001.0
# 4        A5   10002.0
# ..      ...       ...
# 95      A96  100000.0
# 96      A97   10000.0
# 97      A98   10001.0
# 98      A99   10002.0
# 99     A100  100000.0
#
# [100 rows x 2 columns]

# %%
Inp5=pd.merge(Inp3,Inp4,on='Customer')

# %%
Inp5
# Out:
#       Sl No: Customer      Month          Type     Amount     Limit
# 0          1       A1  12-Jan-04     JEWELLERY  485470.80  500000.0
# 1          2       A1   3-Jan-04         PETRO  410556.13  500000.0
# 2          3       A1  15-Jan-04       CLOTHES   23740.46  500000.0
# 3          4       A1  25-Jan-04          FOOD  484342.47  500000.0
# 4          5       A1  17-Jan-05        CAMERA  369694.07  500000.0
# ...      ...      ...        ...           ...        ...       ...
# 1495     277       A7   3-May-06    AIR TICKET  305050.62  100001.0
# 1496     295       A7  23-Feb-05        CAMERA  314704.54  100001.0
# 1497     313       A7  12-Jan-04          AUTO  498358.28  100001.0
# 1498     331       A7  25-Jan-04  TRAIN TICKET  461282.47  100001.0
# 1499     349       A7  19-Apr-06     JEWELLERY  165956.43  100001.0
#
# [1500 rows x 6 columns]

# %%
Inp5.where(Inp5.Amount>Inp5.Limit).dropna()
# Out:
#       Sl No: Customer      Month          Type     Amount     Limit
# 18       8.0       A8   5-Feb-04          BIKE  155562.58  100002.0
# 19     110.0       A8  12-Jan-04        CAMERA  470561.03  100002.0
# 20     124.0       A8  31-Mar-06  TRAIN TICKET  113366.26  100002.0
# 21     138.0       A8   9-May-05         PETRO  371894.08  100002.0
# 22     152.0       A8  29-May-05        CAMERA  335298.81  100002.0
# ...      ...      ...        ...           ...        ...       ...
# 1495   277.0       A7   3-May-06    AIR TICKET  305050.62  100001.0
# 1496   295.0       A7  23-Feb-05        CAMERA  314704.54  100001.0
# 1497   313.0       A7  12-Jan-04          AUTO  498358.28  100001.0
# 1498   331.0       A7  25-Jan-04  TRAIN TICKET  461282.47  100001.0
# 1499   349.0       A7  19-Apr-06     JEWELLERY  165956.43  100001.0
#
# [607 rows x 6 columns]

# %%
Inp5['Amount']=np.where(Inp5.Amount>Inp5.Limit,(Inp5.Limit)/2,Inp5.Amount)

# %%
Inp5.tail(10)
# Out:
#       Sl No: Customer      Month          Type   Amount     Limit
# 1490     207       A7  25-Jan-04          FOOD  50000.5  100001.0
# 1491     221       A7  15-Jan-04       CLOTHES  50000.5  100001.0
# 1492     235       A7  19-Mar-04       CLOTHES  50000.5  100001.0
# 1493     249       A7  11-Jul-06         PETRO  50000.5  100001.0
# 1494     259       A7  27-May-05         PETRO  50000.5  100001.0
# 1495     277       A7   3-May-06    AIR TICKET  50000.5  100001.0
# 1496     295       A7  23-Feb-05        CAMERA  50000.5  100001.0
# 1497     313       A7  12-Jan-04          AUTO  50000.5  100001.0
# 1498     331       A7  25-Jan-04  TRAIN TICKET  50000.5  100001.0
# 1499     349       A7  19-Apr-06     JEWELLERY  50000.5  100001.0

# %%
###c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
Inp2
# Out:
#       SL No: Customer      Month     Amount
# 0        NaN       A1  12-Jan-04  495414.75
# 1        2.0       A1   3-Jan-04  245899.02
# 2        3.0       A1  15-Jan-04  259490.06
# 3        4.0       A1  25-Jan-04  437555.12
# 4        5.0       A1  17-Jan-05  165972.88
# ...      ...      ...        ...        ...
# 1495  1496.0      A67   9-May-05   55638.77
# 1496  1497.0      A68  10-May-06  319836.49
# 1497  1498.0      A69  11-Jul-06  247628.45
# 1498  1499.0      A70  12-Aug-05  454016.51
# 1499  1500.0      A71  13-Sep-04   56286.33
#
# [1500 rows x 4 columns]

# %%
Inp6=pd.merge(Inp2,Inp4,on='Customer')

# %%
Inp6
# Out:
#       SL No: Customer      Month     Amount     Limit
# 0        NaN       A1  12-Jan-04  495414.75  500000.0
# 1        2.0       A1   3-Jan-04  245899.02  500000.0
# 2        3.0       A1  15-Jan-04  259490.06  500000.0
# 3        4.0       A1  25-Jan-04  437555.12  500000.0
# 4        5.0       A1  17-Jan-05  165972.88  500000.0
# ...      ...      ...        ...        ...       ...
# 1495   277.0       A7  22-Nov-05   55108.71  100001.0
# 1496   295.0       A7   3-Dec-05  429700.12  100001.0
# 1497   313.0       A7  23-Feb-05  344628.72  100001.0
# 1498   331.0       A7  31-Mar-06  336264.37  100001.0
# 1499   349.0       A7   3-Jan-04  473662.61  100001.0
#
# [1500 rows x 5 columns]

# %%
Inp6['Amount']=np.where(Inp6.Amount>Inp6.Limit,Inp6.Limit,Inp6.Amount)

# %%
Inp6
# Out:
#       SL No: Customer      Month     Amount     Limit
# 0        NaN       A1  12-Jan-04  495414.75  500000.0
# 1        2.0       A1   3-Jan-04  245899.02  500000.0
# 2        3.0       A1  15-Jan-04  259490.06  500000.0
# 3        4.0       A1  25-Jan-04  437555.12  500000.0
# 4        5.0       A1  17-Jan-05  165972.88  500000.0
# ...      ...      ...        ...        ...       ...
# 1495   277.0       A7  22-Nov-05   55108.71  100001.0
# 1496   295.0       A7   3-Dec-05  100001.00  100001.0
# 1497   313.0       A7  23-Feb-05  100001.00  100001.0
# 1498   331.0       A7  31-Mar-06  100001.00  100001.0
# 1499   349.0       A7   3-Jan-04  100001.00  100001.0
#
# [1500 rows x 5 columns]

# %%
##2. From the above dataset create the following summaries:
##a. How many distinct customers exist?
##b. How many distinct categories exist?
##c. What is the average monthly spend by customers?
##d. What is the average monthly repayment by customers?
##e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?
##(Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment
##– Monthly spend. Interest is earned only on positive profits and not on negative amounts)
##f. What are the top 5 product types?
##g. Which city is having maximum spend?
##h. Which age group is spending more money?
##i. Who are the top 10 customers in terms of repayment?

# %%
##a. How many distinct customers exist?

np.count_nonzero(Inp1.Customer.unique())
# Out:
# 100

# %%
##b. How many distinct categories exist

np.count_nonzero(Inp1.Segment.unique())
# Out:
# 5

# %%
##c. What is the average monthly spend by customers?

Inp3.Month
# Out:
# 0       12-Jan-04
# 1        3-Jan-04
# 2       15-Jan-04
# 3       25-Jan-04
# 4       17-Jan-05
#           ...
# 1495     4-Feb-06
# 1496    25-Mar-06
# 1497    31-Mar-06
# 1498    23-Mar-06
# 1499    24-Mar-06
# Name: Month, Length: 1500, dtype: object

# %%
Inp3['Month']=pd.to_datetime(Inp3.Month,format='%d-%b-%y')

# %%
Inp3.sort_values('Month')
# Out:
#       Sl No: Customer      Month          Type     Amount
# 749      750      A43 2004-01-03          FOOD  330665.44
# 862      863      A40 2004-01-03        CAMERA   34362.04
# 437      438      A28 2004-01-03        CAMERA  244467.34
# 866      867      A44 2004-01-03  TRAIN TICKET  151668.91
# 67        68      A66 2004-01-03          BIKE  321903.62
# ...      ...      ...        ...           ...        ...
# 1482    1483      A56 2006-12-03     JEWELLERY  223628.27
# 1155    1156      A58 2006-12-03       CLOTHES  167643.95
# 610      611      A30 2006-12-03  TRAIN TICKET   26024.81
# 1373    1374      A44 2006-12-03     JEWELLERY  313591.17
# 65        66      A64 2006-12-03       SANDALS  393513.71
#
# [1500 rows x 5 columns]

# %%
Inp3['MNTH']=pd.DatetimeIndex(Inp3.Month).month
Inp3['YEAR']=pd.DatetimeIndex(Inp3.Month).year
Inp3['DATE']=Inp3.MNTH.astype(str)+'-'+Inp3.YEAR.astype(str)

# %%
Inp3
# Out:
#       Sl No: Customer      Month        Type     Amount  MNTH  YEAR    DATE
# 0          1       A1 2004-01-12   JEWELLERY  485470.80     1  2004  1-2004
# 1          2       A1 2004-01-03       PETRO  410556.13     1  2004  1-2004
# 2          3       A1 2004-01-15     CLOTHES   23740.46     1  2004  1-2004
# 3          4       A1 2004-01-25        FOOD  484342.47     1  2004  1-2004
# 4          5       A1 2005-01-17      CAMERA  369694.07     1  2005  1-2005
# ...      ...      ...        ...         ...        ...   ...   ...     ...
# 1495    1496      A67 2006-02-04  BUS TICKET  356872.73     2  2006  2-2006
# 1496    1497      A68 2006-03-25  BUS TICKET  204971.10     3  2006  3-2006
# 1497    1498      A69 2006-03-31  BUS TICKET   50449.44     3  2006  3-2006
# 1498    1499      A70 2006-03-23  BUS TICKET   80593.94     3  2006  3-2006
# 1499    1500      A71 2006-03-24  BUS TICKET  194447.62     3  2006  3-2006
#
# [1500 rows x 8 columns]

# %%
df_spend=pd.DataFrame(Inp3.groupby('DATE').Amount.mean())

# %%
df_spend
# Out:
#                 Amount
# DATE
# 1-2004   251712.068664
# 1-2005   292741.372857
# 1-2006   282058.006429
# 10-2005  194568.640714
# 10-2006  236136.335000
# 11-2004  270486.397857
# 11-2005  286143.322857
# 11-2006  182841.290000
# 12-2005  147503.060000
# 12-2006  270470.980714
# 2-2004   221215.270000
# 2-2005   229802.279821
# 2-2006   253858.260714
# 3-2004   232146.119286
# 3-2006   247166.084654
# 4-2004   235272.037143
# 4-2005   252181.326429
# 4-2006   232468.967553
# 5-2004   217539.236429
# 5-2005   245696.515429
# 5-2006   236162.740357
# 6-2005   262688.112857
# 6-2006   177252.386429
# 7-2005   229116.663571
# 7-2006   287505.098929
# 8-2005   233734.634286
# 8-2006   240699.717143
# 9-2004   310923.383571
# 9-2005   188666.202143
# 9-2006   158520.090714

# %%
df_spend.reset_index(inplace=True)

# %%
df_spend.rename(columns={'Amount':'Spend_Amount'},inplace=True)

# %%
###d. What is the average monthly repayment by customers?

Inp2
# Out:
#       SL No: Customer      Month     Amount
# 0        NaN       A1  12-Jan-04  495414.75
# 1        2.0       A1   3-Jan-04  245899.02
# 2        3.0       A1  15-Jan-04  259490.06
# 3        4.0       A1  25-Jan-04  437555.12
# 4        5.0       A1  17-Jan-05  165972.88
# ...      ...      ...        ...        ...
# 1495  1496.0      A67   9-May-05   55638.77
# 1496  1497.0      A68  10-May-06  319836.49
# 1497  1498.0      A69  11-Jul-06  247628.45
# 1498  1499.0      A70  12-Aug-05  454016.51
# 1499  1500.0      A71  13-Sep-04   56286.33
#
# [1500 rows x 4 columns]

# %%
Inp2['Month']=pd.to_datetime(Inp2.Month,format='%d-%b-%y')

# %%
Inp2['MNTH']=pd.DatetimeIndex(Inp2.Month).month
Inp2['YEAR']=pd.DatetimeIndex(Inp2.Month).year

# %%
Inp2['Date']=Inp2['MNTH'].astype(str)+'-'+Inp2['YEAR'].astype(str)

# %%
Inp2
# Out:
#       SL No: Customer      Month     Amount  MNTH  YEAR    Date
# 0        NaN       A1 2004-01-12  495414.75     1  2004  1-2004
# 1        2.0       A1 2004-01-03  245899.02     1  2004  1-2004
# 2        3.0       A1 2004-01-15  259490.06     1  2004  1-2004
# 3        4.0       A1 2004-01-25  437555.12     1  2004  1-2004
# 4        5.0       A1 2005-01-17  165972.88     1  2005  1-2005
# ...      ...      ...        ...        ...   ...   ...     ...
# 1495  1496.0      A67 2005-05-09   55638.77     5  2005  5-2005
# 1496  1497.0      A68 2006-05-10  319836.49     5  2006  5-2006
# 1497  1498.0      A69 2006-07-11  247628.45     7  2006  7-2006
# 1498  1499.0      A70 2005-08-12  454016.51     8  2005  8-2005
# 1499  1500.0      A71 2004-09-13   56286.33     9  2004  9-2004
#
# [1500 rows x 7 columns]

# %%
Inp2.groupby('Date').Amount.mean()
# Out:
# Date
# 1-2004     243489.649786
# 1-2005     240548.098148
# 1-2006     293475.389167
# 10-2005    219849.956667
# 10-2006    260765.480000
# 11-2004    209592.238000
# 11-2005    256695.120000
# 11-2006    199399.197407
# 12-2005    320379.335833
# 12-2006    252736.569167
# 2-2004     256702.630741
# 2-2005     238829.265123
# 2-2006     284489.565128
# 3-2004     252585.280667
# 3-2006     240851.266814
# 4-2004     259141.679000
# 4-2005     212688.631333
# 4-2006     275472.251889
# 5-2004     226162.720800
# 5-2005     263207.367857
# 5-2006     256920.884943
# 6-2005     210199.818333
# 6-2006     251990.453333
# 7-2005     239871.479167
# 7-2006     257936.383243
# 8-2005     264430.921622
# 8-2006     224143.992500
# 9-2004     184487.848750
# 9-2005     247700.170000
# 9-2006     262533.880833
# Name: Amount, dtype: float64

# %%
df_repayment=pd.DataFrame(Inp2.groupby('Date').Amount.mean())

# %%
df_repayment.reset_index(inplace=True)

# %%
df_repayment.rename(columns={'Amount':'Repayment_Amount','Date':'DATE'},inplace=True)

# %%
##e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?
##(Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment
##– Monthly spend. Interest is earned only on positive profits and not on negative amounts)

# %%
df_spend.head()
# Out:
#       DATE   Spend_Amount
# 0   1-2004  251712.068664
# 1   1-2005  292741.372857
# 2   1-2006  282058.006429
# 3  10-2005  194568.640714
# 4  10-2006  236136.335000

# %%
df_repayment.head()
# Out:
#       DATE  Repayment_Amount
# 0   1-2004     243489.649786
# 1   1-2005     240548.098148
# 2   1-2006     293475.389167
# 3  10-2005     219849.956667
# 4  10-2006     260765.480000

# %%
df_profit=pd.merge(df_spend,df_repayment,on='DATE')

# %%
df_profit.head()
# Out:
#       DATE   Spend_Amount  Repayment_Amount
# 0   1-2004  251712.068664     243489.649786
# 1   1-2005  292741.372857     240548.098148
# 2   1-2006  282058.006429     293475.389167
# 3  10-2005  194568.640714     219849.956667
# 4  10-2006  236136.335000     260765.480000

# %%
df_profit['Net_Profit']=df_profit['Repayment_Amount']-df_profit['Spend_Amount']

# %%
df_profit.head()
# Out:
#       DATE   Spend_Amount  Repayment_Amount    Net_Profit
# 0   1-2004  251712.068664     243489.649786  -8222.418879
# 1   1-2005  292741.372857     240548.098148 -52193.274709
# 2   1-2006  282058.006429     293475.389167  11417.382738
# 3  10-2005  194568.640714     219849.956667  25281.315952
# 4  10-2006  236136.335000     260765.480000  24629.145000

# %%
df_profit['Net_Pofit']=np.where(df_profit.Net_Profit>0,df_profit.Net_Profit,np.NaN)

# %%
df_profit
# Out:
#        DATE   Spend_Amount  Repayment_Amount     Net_Profit      Net_Pofit
# 0    1-2004  251712.068664     243489.649786   -8222.418879            NaN
# 1    1-2005  292741.372857     240548.098148  -52193.274709            NaN
# 2    1-2006  282058.006429     293475.389167   11417.382738   11417.382738
# 3   10-2005  194568.640714     219849.956667   25281.315952   25281.315952
# 4   10-2006  236136.335000     260765.480000   24629.145000   24629.145000
# 5   11-2004  270486.397857     209592.238000  -60894.159857            NaN
# 6   11-2005  286143.322857     256695.120000  -29448.202857            NaN
# 7   11-2006  182841.290000     199399.197407   16557.907407   16557.907407
# 8   12-2005  147503.060000     320379.335833  172876.275833  172876.275833
# 9   12-2006  270470.980714     252736.569167  -17734.411548            NaN
# 10   2-2004  221215.270000     256702.630741   35487.360741   35487.360741
# ...

# %%
df_profit.dropna(inplace=True)

# %%
df_profit
# Out:
#        DATE   Spend_Amount  Repayment_Amount     Net_Profit      Net_Pofit
# 2    1-2006  282058.006429     293475.389167   11417.382738   11417.382738
# 3   10-2005  194568.640714     219849.956667   25281.315952   25281.315952
# 4   10-2006  236136.335000     260765.480000   24629.145000   24629.145000
# 7   11-2006  182841.290000     199399.197407   16557.907407   16557.907407
# 8   12-2005  147503.060000     320379.335833  172876.275833  172876.275833
# 10   2-2004  221215.270000     256702.630741   35487.360741   35487.360741
# 11   2-2005  229802.279821     238829.265123    9026.985302    9026.985302
# 12   2-2006  253858.260714     284489.565128   30631.304414   30631.304414
# 13   3-2004  232146.119286     252585.280667   20439.161381   20439.161381
# 15   4-2004  235272.037143     259141.679000   23869.641857   23869.641857
# 17   4-2006  232468.967553     275472.251889   43003.284336   43003.284336
# ...

# %%
df_profit['Profit_Earned']=(df_profit.Net_Profit+(df_profit.Net_Profit*2.9)/100)

# %%
df_profit.head(2)
# Out:
#       DATE   Spend_Amount  Repayment_Amount    Net_Profit     Net_Pofit  \
# 2   1-2006  282058.006429     293475.389167  11417.382738  11417.382738
# 3  10-2005  194568.640714     219849.956667  25281.315952  25281.315952
#
#    Profit_Earned
# 2   11748.486837
# 3   26014.474115

# %%
df_profit.sort_values('DATE')
# Out:
#        DATE   Spend_Amount  Repayment_Amount     Net_Profit      Net_Pofit  \
# 2    1-2006  282058.006429     293475.389167   11417.382738   11417.382738
# 3   10-2005  194568.640714     219849.956667   25281.315952   25281.315952
# 4   10-2006  236136.335000     260765.480000   24629.145000   24629.145000
# 7   11-2006  182841.290000     199399.197407   16557.907407   16557.907407
# 8   12-2005  147503.060000     320379.335833  172876.275833  172876.275833
# 10   2-2004  221215.270000     256702.630741   35487.360741   35487.360741
# 11   2-2005  229802.279821     238829.265123    9026.985302    9026.985302
# 12   2-2006  253858.260714     284489.565128   30631.304414   30631.304414
# 13   3-2004  232146.119286     252585.280667   20439.161381   20439.161381
# 15   4-2004  235272.037143     259141.679000   23869.641857   23869.641857
# 17   4-2006  232468.967553     275472.251889   43003.284336   43003.284336
# ...

# %%
##f. What are the top 5 product types?

Inp3.Type.value_counts().head()
# Out:
# PETRO           200
# CAMERA          160
# FOOD            160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: Type, dtype: int64

# %%
##g. Which city is having maximum spend?

Inp1
# Out:
#      No Customer   Age        City   Product     Limit Company        Segment
# 0     1       A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3  34.0      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4  47.0      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5  56.0   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...   ...         ...       ...       ...     ...            ...
# 95   96      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
Inp3.groupby('Customer').Amount.sum().sort_values()
# Out:
# Customer
# A89       24972.02
# A88       26518.91
# A76       30066.44
# A77       31048.93
# A73       47380.56
#           ...
# A61     9002326.39
# A21     9003797.18
# A40     9061868.60
# A38     9102803.62
# A60    11020930.98
# Name: Amount, Length: 100, dtype: float64

# %%
## Above analysis shows A60 spend maximum amount,so we will find city corresponding to A60

Inp1.loc[59:59,:]

###maximum spend by CALCUTTA
# Out:
#     No Customer   Age      City Product     Limit Company       Segment
# 59  60      A60  28.0  CALCUTTA    Gold  500000.0     C22  Salaried_Pvt

# %%
##h. Which age group is spending more money?

Inp3.groupby('Customer').Amount.sum().sort_values().tail()
# Out:
# Customer
# A61     9002326.39
# A21     9003797.18
# A40     9061868.60
# A38     9102803.62
# A60    11020930.98
# Name: Amount, dtype: float64

# %%
### Top 5 spending pattern is shown by Customers(A47,A12,A13,A22,A36,A61,A21,A40,A38,A60) we will find the age groups of these Customers

Inp1.iloc[[60,20,39,37,59]]
# Out:
#     No Customer   Age      City   Product     Limit Company        Segment
# 60  61      A61  44.0    COCHIN      Gold  500000.0     C23           Govt
# 20  21      A21  57.0    COCHIN  Platimum   10002.0     C21  Normal Salary
# 39  40      A40  37.0  CALCUTTA  Platimum  500000.0     C22   Salaried_Pvt
# 37  38      A38  47.0   CHENNAI  Platimum  500000.0     C20  Self Employed
# 59  60      A60  28.0  CALCUTTA      Gold  500000.0     C22   Salaried_Pvt

# %%
## Age between 28-57 yrs is spending maximum

# %%
##i. Who are the top 10 customers in terms of repayment?

Inp2.groupby('Customer').Amount.sum().sort_values().tail(10)
# Out:
# Customer
# A14     7943268.63
# A48     8292416.75
# A12     8334760.16
# A45     8448334.87
# A43     8489871.46
# A21     9056336.15
# A22     9372561.68
# A13     9572000.66
# A60     9876290.74
# A61    10539142.91
# Name: Amount, dtype: float64

# %%
##3. Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.

# %%
Inp3.head()
# Out:
#    Sl No: Customer      Month       Type     Amount  MNTH  YEAR    DATE
# 0       1       A1 2004-01-12  JEWELLERY  485470.80     1  2004  1-2004
# 1       2       A1 2004-01-03      PETRO  410556.13     1  2004  1-2004
# 2       3       A1 2004-01-15    CLOTHES   23740.46     1  2004  1-2004
# 3       4       A1 2004-01-25       FOOD  484342.47     1  2004  1-2004
# 4       5       A1 2005-01-17     CAMERA  369694.07     1  2005  1-2005

# %%
A1=Inp3.iloc[:,[1,3,4,5,6]]

# %%
Inp1.head()
# Out:
#    No Customer   Age       City   Product     Limit Company        Segment
# 0   1       A1  76.0  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2  71.0   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3  34.0     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4  47.0     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5  56.0  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
A2=Inp1.iloc[:,[1,3]]

# %%
df_cty_wise_info=pd.merge(A1,A2,on='Customer')

# %%
df_cty_wise_info.head()
# Out:
#   Customer       Type     Amount  MNTH  YEAR       City
# 0       A1  JEWELLERY  485470.80     1  2004  BANGALORE
# 1       A1      PETRO  410556.13     1  2004  BANGALORE
# 2       A1    CLOTHES   23740.46     1  2004  BANGALORE
# 3       A1       FOOD  484342.47     1  2004  BANGALORE
# 4       A1     CAMERA  369694.07     1  2005  BANGALORE

# %%
##CWS=df_cty_wise_info.groupby(['YEAR','City','Type']).Amount.sum()
CWS=df_cty_wise_info.groupby(['YEAR','City']).Amount.sum()

# %%
CWS=CWS.reset_index()

# %%
CWS.head(10)
# Out:
#    YEAR        City       Amount
# 0  2004   BANGALORE  22110544.12
# 1  2004      BOMBAY  15249239.61
# 2  2004    CALCUTTA  16760270.01
# 3  2004     CHENNAI   7774320.55
# 4  2004      COCHIN  20376421.08
# 5  2004       DELHI   8664919.18
# 6  2004       PATNA   6584433.15
# 7  2004  TRIVANDRUM   6972433.90
# 8  2005   BANGALORE  24612625.89
# 9  2005      BOMBAY  16485468.73

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
Order1=['Banglore','Bombay','Calcutta','Chennai','Cochin','Delhi','Patna','Trivandrum']

# %%
##sns.barplot(CWS.City,CWS.Amount,hue=CWS.YEAR,order=Order1,orient="v")
##when  am using this command my graph is not visible?

# %%
sns.barplot(CWS.City,CWS.Amount,hue=CWS.YEAR,orient="v")

# %%
##4. Create graphs for
##a. Monthly comparison of total spends, city wise
##b. Comparison of yearly spend on air tickets
##c. Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)

# %%
##a. Monthly comparison of total spends, city wise

df_cty_wise_info.head()
# Out:
#   Customer       Type     Amount  MNTH  YEAR       City
# 0       A1  JEWELLERY  485470.80     1  2004  BANGALORE
# 1       A1      PETRO  410556.13     1  2004  BANGALORE
# 2       A1    CLOTHES   23740.46     1  2004  BANGALORE
# 3       A1       FOOD  484342.47     1  2004  BANGALORE
# 4       A1     CAMERA  369694.07     1  2005  BANGALORE

# %%
CWS1=df_cty_wise_info.groupby(['MNTH','City']).Amount.sum().reset_index()

# %%
CWS1.head()
# Out:
#    MNTH       City       Amount
# 0     1  BANGALORE  17782487.66
# 1     1     BOMBAY  10681854.60
# 2     1   CALCUTTA  14163384.38
# 3     1    CHENNAI   7649568.68
# 4     1     COCHIN  18692606.60

# %%
sns.barplot(CWS1.MNTH,CWS1.Amount,hue=CWS1.City,orient="v")

# %%
##b. Comparison of yearly spend on air tickets

df_cty_wise_info['TYPE']  =df_cty_wise_info.Type.where(df_cty_wise_info.Type=='AIR TICKET')

# %%
P1=df_cty_wise_info.dropna()

# %%
B1=P1.groupby('YEAR').Amount.sum()

# %%
B2=B1.reset_index()

# %%
B2
# Out:
#    YEAR       Amount
# 0  2004   8370914.59
# 1  2005  14495718.73
# 2  2006  10088812.10

# %%
plt.bar(B2.YEAR,B2.Amount,width=0.3)
# Out:
# <BarContainer object of 3 artists>

# %%
##c. Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)

# %%
CC1=df_cty_wise_info.groupby(['MNTH']).Amount.sum().reset_index()

# %%
CC1
# Out:
#     MNTH       Amount
# 0      1  89421175.61
# 1      2  55462857.52
# 2      3  56885086.04
# 3      4  35500777.13
# 4      5  50668174.93
# 5      6  13514434.15
# 6      7  11257776.06
# 7      8   9914365.80
# 8      9   9213535.47
# 9     10   6029869.66
# 10    11  20924385.25
# 11    12   5851636.57

# %%
CC1.plot('MNTH','Amount',kind='bar')

# %%
##5. Write user defined PYTHON function to perform the following analysis:
##You need to find top 10 customers for each city in terms of their repayment amount by
##different products and by different time periods i.e. year or month. The user should be able
##to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the
##function should automatically take these inputs while identifying the top 10 customers.

# %%
Inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
# No          100 non-null int64
# Customer    100 non-null object
# Age         100 non-null float64
# City        100 non-null object
# Product     100 non-null object
# Limit       100 non-null float64
# Company     100 non-null object
# Segment     100 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 6.4+ KB

# %%
Inp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
# SL No:      1499 non-null float64
# Customer    1500 non-null object
# Month       1500 non-null datetime64[ns]
# Amount      1500 non-null float64
# MNTH        1500 non-null int64
# YEAR        1500 non-null int64
# Date        1500 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 93.8+ KB

# %%
df_udf=pd.merge(Inp1,Inp2,on='Customer')

# %%
dfG_2004=df_udf.iloc[np.where((df_udf.Product=='Gold') & (df_udf.YEAR==2004))]
dfG_2005=df_udf.iloc[np.where((df_udf.Product=='Gold') & (df_udf.YEAR==2005))]
dfG_2006=df_udf.iloc[np.where((df_udf.Product=='Gold') & (df_udf.YEAR==2006))]
dfS_2004=df_udf.iloc[np.where((df_udf.Product=='Silver') & (df_udf.YEAR==2004))]
dfS_2005=df_udf.iloc[np.where((df_udf.Product=='Silver') & (df_udf.YEAR==2005))]
dfS_2006=df_udf.iloc[np.where((df_udf.Product=='Silver') & (df_udf.YEAR==2006))]
dfP_2004=df_udf.iloc[np.where((df_udf.Product=='Platimum') & (df_udf.YEAR==2004))]
dfP_2005=df_udf.iloc[np.where((df_udf.Product=='Platimum') & (df_udf.YEAR==2005))]
dfP_2006=df_udf.iloc[np.where((df_udf.Product=='Platimum') & (df_udf.YEAR==2006))]

# %%
df_udf.Product.unique()
# Out:
# array(['Gold', 'Silver', 'Platimum'], dtype=object)

# %%
##dfG_2004
##dfG_2005
##dfG_2006
##dfS_2004
##dfS_2005
##dfS_2006
##dfP_2004
##dfP_2005
dfP_2006
# Out:
#       No Customer   Age      City   Product     Limit Company        Segment  \
# 35     3       A3  34.0    COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 36     3       A3  34.0    COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 37     3       A3  34.0    COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 46     4       A4  47.0    BOMBAY  Platimum   10001.0      C4           Govt
# 47     4       A4  47.0    BOMBAY  Platimum   10001.0      C4           Govt
# ...   ..      ...   ...       ...       ...       ...     ...            ...
# 1296  56      A56  60.0   CHENNAI  Platimum  500000.0     C18  Normal Salary
# 1297  56      A56  60.0   CHENNAI  Platimum  500000.0     C18  Normal Salary
# 1299  56      A56  60.0   CHENNAI  Platimum  500000.0     C18  Normal Salary
# 1466  69      A69  33.0  CALCUTTA  Platimum   10000.0     C31  Self Employed
# 1482  83      A83  37.0    COCHIN  Platimum   10002.0      C6           Govt
#
# ...

# %%
dfG_2004.City.unique()
# Out:
# array(['BANGALORE', 'CALCUTTA', 'COCHIN', 'BOMBAY', 'PATNA', 'CHENNAI',
#        'TRIVANDRUM', 'DELHI'], dtype=object)

# %%
P1=dfG_2004.groupby(['City','Customer']).Amount.sum().reset_index()

# %%
def top10_user(Product,Time):
    if((Product=='Gold')&(Time==2004)):
        P1=dfG_2004.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P1)
    elif((Product=='Gold')&(Time==2005)):
        P2=dfG_2005.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P2)
    elif((Product=='Gold')&(Time==2006)):
        P3=dfG_2006.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P3)
    elif((Product=='Silver')&(Time==2004)):
        P4=dfS_2004.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P4)
    elif((Product=='Silver')&(Time==2005)):
        P5=dfS_2005.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P5)
    elif((Product=='Silver')&(Time==2006)):
        P6=dfS_2005.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P6)
    elif((Product=='Platimum')&(Time==2004)):
        P7=dfP_2004.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P7)
    elif((Product=='Platimum')&(Time==2005)):
        P8=dfP_2005.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P8)
    elif((Product=='Platimum')&(Time==2006)):
        P9=dfP_2005.groupby(['City','Customer']).Amount.sum().reset_index().sort_values(by=['City','Amount'],ascending=(True,False))
        return(P9)

# %%
top10_user(Product='Silver',Time=2004)
# Out:
#           City Customer      Amount
# 1    BANGALORE      A23  2168566.91
# 2    BANGALORE      A59  1777966.35
# 0    BANGALORE      A18  1561795.61
# 3    BANGALORE      A72   327006.94
# 4       BOMBAY      A22  3455774.79
# 6     CALCUTTA      A58  1139773.34
# 5     CALCUTTA       A2   811338.80
# 7      CHENNAI       A9  1200994.06
# 8      CHENNAI      A96   310992.30
# 10      COCHIN      A25  1873963.99
# 11      COCHIN       A7  1377007.07
# 9       COCHIN     A100    69551.19
# 13       DELHI       A6  1670502.81
# 12       DELHI      A24   607204.99
# 15       PATNA       A8  2573830.15
# 14       PATNA      A46  1872231.20
# 16  TRIVANDRUM      A57  2732428.36
# 17  TRIVANDRUM      A68   105098.26
