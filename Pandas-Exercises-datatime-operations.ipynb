# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %% [raw]
# """
# Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
# 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
# """

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %% [markdown]
# ### Step 2. Import the dataset [wind.csv](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data) from the folder

# %%
data=pd.read_csv(r'C:\Users\Isha Kaushal\Downloads\wind.data')

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data['Date']=data.Dy.astype(str)+'-'+data.Mo.astype(str)+'-'+(data.Yr).astype(str)

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL      Date
# 0     10.83  12.58  18.50  15.04    1-1-61
# ...

# %%
data['Date']=pd.to_datetime(data.Date,format='%d-%m-%y')

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date
# 0     10.83  12.58  18.50  15.04 2061-01-01
# ...

# %%
data.sort_values('Date')
# Out:
#       Yr  Mo  Dy    RPT   VAL    ROS   KIL   SHA   BIR    DUB   CLA    MUL  \
# 2922  69   1   1   6.13  1.63   5.41  1.08  2.54  1.00   8.50  2.42   4.58
# 2923  69   1   2   2.62  0.54   6.71  2.88  5.63  1.13   7.75  1.87   5.83
# 2924  69   1   3   4.17  2.37   6.29  1.67  4.00  2.37   7.96  5.41   5.04
# 2925  69   1   4   6.00  6.87   7.67  4.63  9.50  5.04  11.25  6.87   8.58
# 2926  69   1   5  10.50  8.38   7.71  3.50  5.41  2.42   7.67  5.37   4.17
# ...   ..  ..  ..    ...   ...    ...   ...   ...   ...    ...   ...    ...
# 2917  68  12  27  12.21  3.96  15.71  5.83  6.67  3.42   9.87  5.46   7.21
# 2918  68  12  28  16.96  7.75  18.00  7.79  9.17  5.88  10.46  4.25   9.25
# 2919  68  12  29  16.62  5.96  16.88  5.00  8.83  5.41  10.83  5.54  10.88
# 2920  68  12  30  12.96  7.08  12.25  4.25  5.63  2.25   7.58  4.12   7.54
# 2921  68  12  31   9.13  2.13   7.38  2.50  4.04  0.50   6.83  2.54   3.54
#
#         CLO    BEL    MAL       Date
# ...

# %% [markdown]
# ### Step 4. Year 2061 is seemingly imporoper. Convert every year which are < 70 to 19XX instead of 20XX.

# %%
data['Date']=pd.np.where(data.Yr<69, data.Date+pd.DateOffset(years=-100),data.Date+pd.DateOffset(years=0))

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date
# 0     10.83  12.58  18.50  15.04 1961-01-01
# ...

# %%
data.sort_values('Date')
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date
# 0     10.83  12.58  18.50  15.04 1961-01-01
# ...

# %%
data.drop(columns=['Yr','Mo','Dy'])
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL       Date
# 0     18.50  15.04 1961-01-01
# ...

# %%
data.sort_values('Date')
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date
# 0     10.83  12.58  18.50  15.04 1961-01-01
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index(data.Date)
# Out:
#             Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# Date
# 1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...         ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 2078-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 2078-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 2078-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 2078-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 2078-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#               CLA    MUL    CLO    BEL    MAL       Date
# Date
# ...

# %%
data.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isna().sum()
# Out:
# Yr      0
# Mo      0
# Dy      0
# RPT     6
# VAL     3
# ROS     2
# KIL     5
# SHA     2
# BIR     0
# DUB     3
# CLA     2
# MUL     3
# CLO     1
# BEL     0
# MAL     4
# Date    0
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.count()
# Out:
# Yr      6574
# Mo      6574
# Dy      6574
# RPT     6568
# VAL     6571
# ROS     6572
# KIL     6569
# SHA     6572
# BIR     6574
# DUB     6571
# CLA     6572
# MUL     6571
# CLO     6573
# BEL     6574
# MAL     6570
# Date    6574
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.loc[:,'RPT':'MAL'].mean()
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %%
data.loc[:,'RPT':'MAL'].mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=pd.DataFrame({'MIN':data.loc[:,'RPT':'MAL'].min(),'MAX':data.loc[:,'RPT':'MAL'].max(),'MEAN':data.loc[:,'RPT':'MAL'].mean(),'STD':data.loc[:,'RPT':'MAL'].std()})

# %%
loc_stats
# Out:
#       MIN    MAX       MEAN       STD
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
data.sort_values(by='Date')
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date
# 0     10.83  12.58  18.50  15.04 1961-01-01
# ...

# %%
day_stats=pd.DataFrame({'MIN':data.groupby(by=data.Dy).mean().loc[:,'RPT':'MAL'].T.min(),'MAX':data.groupby(by=data.Dy).mean().loc[:,'RPT':'MAL'].T.max(),'MEAN':data.groupby(by=data.Dy).mean().loc[:,'RPT':'MAL'].T.mean(),'STD':data.groupby(by=data.Dy).mean().loc[:,'RPT':'MAL'].T.min()})

# %%
day_stats
# Out:
#          MIN        MAX       MEAN       STD
# Dy
# 1   6.498796  15.945395  10.532077  6.498796
# 2   6.613981  15.830463  10.390175  6.613981
# 3   6.195324  15.499491   9.918786  6.195324
# 4   5.943472  15.173380   9.808995  5.943472
# 5   6.021528  15.998333  10.114915  6.021528
# 6   6.096296  15.423194  10.015224  6.096296
# 7   6.311389  15.124306  10.100985  6.311389
# 8   6.091852  15.332361   9.902049  6.091852
# 9   6.361898  15.879352  10.399803  6.361898
# 10  6.550463  15.592083  10.529325  6.550463
# 11  6.455000  15.772454  10.563180  6.455000
# 12  6.606065  15.787546  10.497737  6.606065
# 13  6.182639  14.981991   9.889074  6.182639
# 14  6.458981  15.271907  10.373006  6.458981
# 15  6.335602  15.120417  10.073495  6.335602
# 16  6.253241  16.157442  10.291646  6.253241
# 17  6.420046  15.662130  10.374973  6.420046
# 18  6.264791  15.415463  10.153698  6.264791
# 19  6.212326  15.737176  10.217497  6.212326
# 20  6.102639  15.714444  10.069841  6.102639
# ...

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data.loc[:,'RPT':'MAL'].groupby(by=data.Mo).mean().head(1)
# Out:
#           RPT       VAL        ROS       KIL        SHA       BIR        DUB  \
# Mo
# 1   14.847325  12.91456  13.299624  7.199498  11.667734  8.054839  11.819355
#
#          CLA       MUL        CLO       BEL        MAL
# Mo
# 1   9.512047  9.543208  10.053566  14.55052  18.028763

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date
# 0     10.83  12.58  18.50  15.04 1961-01-01
# ...

# %%
data.loc[:,'RPT':'MAL'].groupby(by=data.Yr).mean()
# Out:
#           RPT        VAL        ROS       KIL        SHA       BIR        DUB  \
# Yr
# 61  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726   9.733923
# 62  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068  11.020712
# 63  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712  11.075699
# 64  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874  10.259153
# 65  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110  10.618712
# 66  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671  10.579808
# 67  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164  10.652027
# 68  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322   8.859180
# 69  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973   8.564493
# 70  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452   9.609890
# 71  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151   8.385890
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
data.loc[:,'RPT':'MAL'].groupby(by=data.Mo).mean()
# Out:
#           RPT        VAL        ROS       KIL        SHA       BIR        DUB  \
# Mo
# 1   14.847325  12.914560  13.299624  7.199498  11.667734  8.054839  11.819355
# 2   13.710906  12.111122  12.879132  6.942411  11.551772  7.633858  11.206024
# 3   13.158687  11.505842  12.648118  7.265907  11.554516  7.959409  11.310179
# 4   12.555648  10.429759  12.204815  6.898037  10.677667  7.441389  10.221315
# 5   11.724032  10.145619  11.550394  6.307487  10.224301  6.942061   8.797738
# 6   10.451317   8.949704  10.361315  5.652278   9.529926  6.410093   8.009556
# 7    9.992007   8.357778   9.349642  5.416935   9.302634  5.972348   7.843501
# 8   10.213411   8.415143   9.993441  5.270681   8.901559  5.891057   7.772312
# 9   11.458519   9.981002  10.756883  5.615176   9.766315  6.566222   8.609722
# 10  12.660610  11.010681  11.453943  6.065215  10.550251  7.159910   9.387778
# 11  13.200722  11.639500  12.293407  6.247611  10.501130  7.134333  10.814861
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data['Week']=data.Date.apply(lambda x : x.week)

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date  Week
# ...

# %%
data.drop(columns=['Yr','Mo','Dy'])
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL       Date  Week
# ...

# %%
data.groupby(data.Week).mean()
# Out:
#              Yr         Mo         Dy        RPT        VAL        ROS  \
# Week
# 1     69.393701   2.212598   7.535433  13.561024  11.076270  12.725827
# 2     69.500000   1.000000  11.166667  16.146349  14.113016  14.579683
# 3     69.500000   1.000000  18.166667  14.546825  13.021984  12.936349
# 4     69.500000   1.000000  25.166667  15.333680  13.527222  13.497063
# 5     69.500000   1.595238  13.714286  14.700317  13.169444  13.176746
# 6     69.500000   2.000000   8.166667  13.022302  11.210000  11.902143
# 7     69.500000   2.000000  15.166667  14.230397  12.338730  13.211190
# 8     69.500000   2.000000  22.166667  13.866349  12.079762  13.711429
# 9     69.500000   2.563492  13.301587  12.793520  12.001825  12.541840
# 10    69.500000   3.000000   7.944444  13.538800  11.937698  13.322063
# 11    69.500000   3.000000  14.944444  12.956270  10.824048  12.469365
# 12    69.500000   3.000000  21.944444  13.637222  12.037302  13.111111
# ...

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
data['month_identifier']=data.Mo.astype(str)+'-'+data.Yr.astype(str)

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date  Week month_identifier
# ...

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date  Week month_identifier
# ...

# %%
data.loc[:,'RPT':'MAL'].groupby(data.month_identifier).mean()
# Out:
#                         RPT        VAL        ROS       KIL        SHA  \
# month_identifier
# 1-61              14.841333  11.988333  13.431613  7.736774  11.072759
# 1-62              14.783871  13.160323  12.591935  7.538065  11.779677
# 1-63              14.868387  11.112903  15.121613  6.635806  11.080645
# 1-64              12.661290  11.818387  11.741290  6.953548  11.400645
# 1-65              15.741613  15.546774  15.274194  8.258387  13.588065
# ...                     ...        ...        ...       ...        ...
# 9-74              14.830667  12.813333  12.155667  6.036667  10.863333
# 9-75              12.666000  10.365333  11.684333  5.446667   9.220000
# 9-76              11.703667  10.515333  10.466333  5.313333   8.761333
# 9-77              12.472333  10.742667  11.849333  5.638667  10.077333
# 9-78              10.913667  10.895000  10.635000  5.725000  10.372000
#
#                        BIR        DUB        CLA        MUL        CLO  \
# month_identifier
# ...

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
data.drop(columns='month_identifier',inplace=True)

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date  Week
# ...

# %%
data['Week']=data.iloc[1:,:].Date.apply(lambda x : x.week)

# %%
data.iloc[1:,:]
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# 5     61   1   6  13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL       Date  Week
# ...

# %%
DATA=data.iloc[1:,:].groupby(['Yr','Week']).mean()

# %%
DATA.drop(columns=['Mo','Dy'],inplace=True)

# %%
DATA
# Out:
#                RPT        VAL        ROS        KIL        SHA        BIR  \
# Yr Week
# 61 1.0   13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
#    2.0   12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
#    3.0   13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
#    4.0   19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
#    5.0   16.827143  15.460000  12.618571   8.247143  13.361429   9.107143
# ...            ...        ...        ...        ...        ...        ...
# 78 48.0  15.054286  12.232857  13.798571   5.571429  10.828571   9.547143
#    49.0  22.215714  20.000000  18.551429  11.194286  16.257143  13.612857
#    50.0  15.270000  13.508571  13.654286   5.398571  10.152857   6.220000
#    51.0  10.781429   7.394286  13.077143   4.242857   7.212857   6.087143
#    52.0  15.050000  11.872500  15.328750   6.728750  10.692500   9.110000
#
# ...

# %%
DATA.iloc[0:52,:]
# Out:
#                RPT        VAL        ROS        KIL        SHA        BIR  \
# Yr Week
# 61 1.0   13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
#    2.0   12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
#    3.0   13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
#    4.0   19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
#    5.0   16.827143  15.460000  12.618571   8.247143  13.361429   9.107143
#    6.0   19.684286  16.417143  17.304286  10.774286  14.718571  12.522857
#    7.0   15.130000  15.091429  13.797143  10.083333  13.410000  11.868571
#    8.0   15.221429  13.625714  14.334286   8.524286  13.655714  10.114286
#    9.0   12.101429  12.951429  11.063333   7.834286  12.101429   9.238571
#    10.0   9.376667  11.578571  10.845714   7.137143  10.940000   9.488571
#    11.0  11.911429  13.501429  11.607143   7.084286  10.751429   8.652857
# ...
